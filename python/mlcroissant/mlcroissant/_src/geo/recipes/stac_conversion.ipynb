# %%
# !cd /home/hks/croissant/python/mlcroissant && pip install -e .[geo]
# Out:
# Obtaining file:///home/hks/croissant/python/mlcroissant
#   Installing build dependencies ... done
#   Checking if build backend supports build_editable ... done
#   Getting requirements to build editable ... done
#   Preparing editable metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.3/9.3 MB 10.1 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 7.6 MB/s eta 0:00:00a 0:00:01m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 9.6 MB/s eta 0:00:00ta 0:00:01
# ...
#   Building editable for mlcroissant (pyproject.toml) ... done
#   Created wheel for mlcroissant: filename=mlcroissant-1.0.21-0.editable-py2.py3-none-any.whl size=7257 sha256=bcdd4eae82dd8f419f22a8bcee53e2d2e0e6ca05dab0a40ed70f55d4085b5c9d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fe2ldi8u/wheels/0b/e1/66/9abfbdfe0af0732a93c6883ce657ddfb5a6b4421a3d390ee78
# Successfully built mlcroissant
# ...

# %%
# import mlcroissant
# from mlcroissant.geo import stac_to_geocroissant

# %%
import mlcroissant
from mlcroissant._src.geo import stac_to_geocroissant

# %%
stac_path = "/home/hks/CEDA/stac.json"
output_path = "/home/hks/CEDA/geo.json"
stac_to_geocroissant(stac_path, output_path)
# Out:
# {'@context': {'@language': 'en',
#   '@vocab': 'https://schema.org/',
#   'cr': 'http://mlcommons.org/croissant/',
#   'geocr': 'http://mlcommons.org/geocroissant/',
#   'dct': 'http://purl.org/dc/terms/',
#   'sc': 'https://schema.org/',
#   'citeAs': 'cr:citeAs',
#   'column': 'cr:column',
#   'conformsTo': 'dct:conformsTo',
#   'data': {'@id': 'cr:data', '@type': '@json'},
#   'dataBiases': 'cr:dataBiases',
#   'dataCollection': 'cr:dataCollection',
#   'dataType': {'@id': 'cr:dataType', '@type': '@vocab'},
#   'extract': 'cr:extract',
#   'field': 'cr:field',
#   'fileProperty': 'cr:fileProperty',
#   'fileObject': 'cr:fileObject',
#   'fileSet': 'cr:fileSet',
#   'format': 'cr:format',
#   'includes': 'cr:includes',
#   'isLiveDataset': 'cr:isLiveDataset',
#   'jsonPath': 'cr:jsonPath',
#   'key': 'cr:key',
#   'md5': {'@id': 'cr:md5', '@type': 'sc:Text'},
#   'sha256': {'@id': 'cr:sha256', '@type': 'sc:Text'},
#   'parentField': 'cr:parentField',
#   'path': 'cr:path',
# ...

# %%
# !mlcroissant validate --jsonld=geo.json
# Out:
# W0810 07:03:56.656389 140173897316160 rdf.py:81] WARNING: The JSON-LD `@context` is not standard. Refer to the official @context (e.g., from the example datasets in https://github.com/mlcommons/croissant/tree/main/datasets/1.0). The different keys are: {'examples', 'rai', 'samplingRate'}
# I0810 07:03:56.675188 140173897316160 validate.py:53] Done.
